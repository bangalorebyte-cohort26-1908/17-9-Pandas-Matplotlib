# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ena.csv')

# %%
type(df) # checking the type of object
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns # getting the column names
# Out:
# Index(['Data Escala de Tempo 1 ENAS Comp 3', 'Subsistema',
#        'Data do Incio da Semana Din Instante ENAS Comp 3',
#        'Data Escala de Tempo 1 ENAS Comp 3.1', 'Período Exibido ENAS',
#        'Subsistema.1', 'Texto Data Incio da Semana Din Instante ENAS',
#        'Selecione Tipo de ENAS Comp 3'],
#       dtype='object')

# %%
df['Selecione Tipo de ENAS Comp 3'].sum() #get sum of aone column
# Out:
# 65887221

# %%
df['Selecione Tipo de ENAS Comp 3'].tail(5).sum() #get su of last 5 items
# Out:
# 7890

# %%
# df.apply()
g = lambda x:x*x
g(5)

df['square'] = df['Selecione Tipo de ENAS Comp 3'].apply(lambda x:x*x)

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.plot()

# %%
df.plot(x='Selecione Tipo de ENAS Comp 3', y='square', kind='scatter')

# %%
import requests
import json

# %%
r = requests.get(url='http://dev.markitondemand.com/MODApis/Api/v2/Lookup/json?input=fb')

# %%
json.loads(r.text)[0]['Symbol']
# Out:
# 'FB'

# %%
r1 = requests.get(url='http://dev.markitondemand.com/Api/v2/Quote/json?symbol='+json.loads(r.text)[0]['Symbol'])

# %%
json.loads(r1.text)['LastPrice']
# Out:
# 186.22
